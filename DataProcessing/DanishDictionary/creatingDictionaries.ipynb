# %% [markdown]
# ---
# ### Gender Dictionary

# %%
import pandas as pd

df = pd.read_csv("/Users/lucasvilsen/Desktop/GrammatikTAK/Datasets/ordlisteFuldform2021rettet.csv")
df.head()
# Out:
#   ord1    ord2 bøjning
# 0    A       A     sb.
# 1    A    A'et     sb.
# 2    A   A'ets     sb.
# 3    A     A's     sb.
# 4    A  A'erne     sb.

# %%
from tqdm import tqdm
# "en" is fællenskøn
dictionary_is_fælleskøn = {}

for i, row in tqdm(df.iterrows()):
    if row['bøjning'] == "sb." and i > 0 and row['ord1'] != df.iloc[i-1]['ord1']:
        word = df.iloc[i+1]['ord2']
        dictionary_is_fælleskøn[df.iloc[i+1]['ord1']] = True if word[-1] == "n" else False
# Out:
# 415437it [00:16, 25030.56it/s]

# %%
dictionary_is_fælleskøn
# Out:
# {'a': False,
#  'A3-format': False,
#  'A4-format': False,
#  'A5-format': False,
#  'A-aktie': True,
#  'abandonnering': True,
#  'abbed': True,
#  'abbedi': False,
#  'abbedisse': True,
#  'ABC': True,
#  'abc': True,
#  'abdicering': True,
#  'abdikation': True,
#  'abe': True,
#  'abefest': True,
#  'abekat': True,
#  'abekattestreg': True,
#  'abemenneske': False,
#  'aber dabei': False,
#  'aberration': True,
#  'abessiner': True,
#  'abessinier': True,
#  'abetræ': False,
#  'abkhaser': True,
#  'ablativ': True,
#  'abnormitet': True,
#  'a-bombe': True,
#  'abonnement': False,
#  'abonnent': True,
#  'abonnering': True,
#  'abonnine': True,
#  'aboriginal': True,
#  'aboriginer': True,
#  'aborre': True,
#  'abort': True,
#  'abortmodstander': True,
#  'abracadabra': False,
#  'A-brev': False,
#  'abrikos': True,
#  'ABS': True,
#  'abs': True,
#  'absces': True,
#  'abscisse': True,
#  'abscisseakse': True,
#  'absence': True,
#  'absentation': True,
#  'absentering': True,
#  'absint': True,
#  'absolut': False,
#  'absolution': True,
#  'absolutisme': True,
#  'absolutist': True,
#  'absorbering': True,
#  'absorption': True,
#  'abstinens': True,
#  'abstract': False,
#  'abstrahering': True,
#  'abstrakt': False,
#  'abstraktion': True,
#  'absurdisme': True,
#  'absurdist': True,
#  'absurditet': True,
#  'abyssinier': True,
#  'acaibær': False,
#  'acceleration': True,
#  'accelerator': True,
#  'accent': True,
#  'accenttegn': False,
#  'accentuation': True,
#  'accentuering': True,
#  'accept': True,
#  'acces': True,
#  'accession': True,
#  'acetat': False,
#  'acetone': True,
#  'acetyl': True,
#  'acetylen': False,
#  'acetylsalicylsyre': True,
#  'acidofilus': False,
#  'a conto-beløb': False,
#  'acontobeløb': False,
#  'action': False,
#  'actionfilm': True,
#  'AD': True,
#  'ad': True,
#  'adagio': True,
#  'adamskostume': False,
#  'adamsæble': False,
#  'adaptation': True,
#  'adapter': True,
#  'adaption': True,
#  'addend': True,
#  'addering': True,
#  'addition': True,
#  'additiv': False,
#  'adel': True,
#  'adelskab': False,
#  'adelskvinde': True,
#  'adelsmand': True,
#  'adelsmærke': False,
#  'adelstand': True,
#  'adelsvælde': True,
#  'adfærd': True,
#  'adfærdsmønster': False,
#  'adfærdsregulering': True,
#  'adfærdsterapi': True,
#  'adgang': True,
#  'adgangsbegrænsning': True,
#  'adgangseksamen': True,
#  'adgangsprøve': True,
#  'adhærence': True,
#  'adhærens': True,
#  'adhæsion': True,
#  'adjektiv': False,
#  'adjudant': True,
#  'adjudantur': True,
#  'adjunkt': True,
#  'adjunktur': False,
#  'adkomst': True,
#  'adled': False,
#  'adling': True,
#  'administration': True,
#  'administrator': True,
#  'administrering': True,
#  'admiral': True,
#  'admiralitet': False,
#  'adonis': True,
#  'adoptant': True,
#  'adoptering': True,
#  'adoption': True,
#  'adoptivbarn': False,
#  'adrenalin': True,
#  'adressat': True,
#  'adresse': True,
#  'adressebog': True,
#  'adressekort': False,
#  'adressering': True,
#  'adskillelse': True,
#  'adsorbering': True,
#  'adsorption': True,
#  'adspredelse': True,
#  'A-dur': False,
#  'advarsel': True,
#  'advarselslampe': True,
#  'advarselstrekant': True,
#  'advent': True,
#  'adventist': True,
#  'adventsgave': True,
#  'adventskrans': True,
#  'adventssøndag': True,
#  'adventure': False,
#  'adverbial': False,
#  'adverbium': False,
#  'advis': True,
#  'advisering': True,
#  'advokat': True,
#  'advokatfuldmægtig': True,
#  'advokatsekretær': True,
#  'advokatur': True,
#  'advokatvagt': True,
#  'aerobic': False,
#  'aerodynamik': True,
#  'aerogram': False,
#  'aerologi': True,
#  'aerosol': True,
#  'afart': True,
#  'afasi': True,
#  'afatiker': True,
#  'afbagning': True,
#  'afbalancering': True,
#  'afbarkning': True,
#  'afbenyttelse': True,
#  'afbeskikkelse': True,
#  'afbestilling': True,
#  'afbestillingsforsikring': True,
#  'afbetaling': True,
#  'afbigt': True,
#  'afbildning': True,
#  'afbinding': True,
#  'afbladning': True,
#  'afblankning': True,
#  'afblegning': True,
#  'afblomstring': True,
#  'afblænding': True,
#  'afblæsning': True,
#  'afbremsning': True,
#  'afbrud': False,
#  'afbrydelse': True,
#  'afbryder': True,
#  'afbrydning': True,
#  'afbræk': False,
#  'afbrækning': True,
#  'afbrænder': True,
#  'afbrænding': True,
#  'afbud': False,
#  'afbureaukratisering': True,
#  'afbødning': True,
#  'afbøjning': True,
#  'afdampning': True,
#  'afdansningsbal': False,
#  'afdeling': True,
#  'afdelingssygeplejerske': True,
#  'afdrag': False,
#  'afdragsfrihed': True,
#  'afdramatisering': True,
#  'afdrift': True,
#  'afdrivning': True,
#  'afdrypning': True,
#  'afdækning': True,
#  'afdæmpning': True,
#  'affald': False,
#  'affaldshåndtering': True,
#  'affaldskværn': True,
#  'affaldsskakt': True,
#  'affaldsstof': False,
#  'affarvning': True,
#  'affattelse': True,
#  'affedning': True,
#  'affedtning': True,
#  'affejning': True,
#  'affekt': True,
#  'affektation': True,
#  'affektion': True,
#  'affektionsværdi': True,
#  'affindelsessum': True,
#  'affinitet': True,
#  'affirmation': True,
#  'affjedring': True,
#  'affladning': True,
#  'affodring': True,
#  'affolkning': True,
#  'affordring': True,
#  'affotografering': True,
#  'affugter': True,
#  'affugtning': True,
#  'affutage': True,
#  'affyring': True,
#  'affærdigelse': True,
#  'affære': True,
#  'affødning': True,
#  'afførelse': True,
#  'afføring': True,
#  'afgang': True,
#  'afgangseksamen': True,
#  'afgangshal': True,
#  'afgangsklasse': True,
#  'afgangsprøve': True,
#  'afgasning': True,
#  'afghaner': True,
#  'afgift': True,
#  'afgiftning': True,
#  'afgivelse': True,
#  'afgivning': True,
#  'afglans': True,
#  'afglatning': True,
#  'afgnavning': True,
#  'afgnidning': True,
#  'afgravning': True,
#  'afgrening': True,
#  'afgrund': True,
#  'afgrænsning': True,
#  'afgræsning': True,
#  'afgrøde': True,
#  'afgrøftning': True,
#  'afgud': True,
#  'afguderi': False,
#  'afgørelse': True,
#  'afhandling': True,
#  'afhaspning': True,
#  'afhentning': True,
#  'afhjemling': True,
#  'afhjælpning': True,
#  'afholdelse': True,
#  'afholdenhed': True,
#  'afholdsbevægelse': True,
#  'afholdsforening': True,
#  'afholdsmand': True,
#  'afhopning': True,
#  'afhopper': True,
#  'afhorning': True,
#  'afhudning': True,
#  'afhugning': True,
#  'afhændelse': True,
#  'afhængighed': True,
#  'afhængighedsfald': False,
#  'afhærdning': True,
#  'afhøring': True,
#  'afhøstning': True,
#  'afhøvling': True,
#  'aficionado': True,
#  'afideologisering': True,
#  'afindustrialisering': True,
#  'afinstallation': True,
#  'afinstallering': True,
#  'afisning': True,
#  'afkald': False,
#  'afkalkning': True,
#  'afkast': False,
#  'afkastning': True,
#  'afklapsning': True,
#  'afklaring': True,
#  'afklædning': True,
#  'afkobling': True,
#  'afkoder': True,
#  'afkodning': True,
#  'afkog': False,
#  'afkogning': True,
#  'afkolonisering': True,
#  'afkom': False,
#  'afkortelse': True,
#  'afkorter': True,
#  'afkortning': True,
#  'afkriminalisering': True,
#  'afkristning': True,
#  'afkrog': True,
#  'afkrydsning': True,
#  'afkræftelse': True,
#  'afkrævning': True,
#  'afkvistning': True,
#  'afkøling': True,
#  'afkørsel': True,
#  'aflad': True,
#  'afladning': True,
#  'afladsbrev': False,
#  'aflastning': True,
#  'aflastningsfamilie': True,
#  'aflatoksin': False,
#  'afleder': True,
#  'afledning': True,
#  'afledningsmanøvre': True,
#  'aflejring': True,
#  'aflevering': True,
#  'afliring': True,
#  'aflivning': True,
#  'aflokkelse': True,
#  'aflukke': False,
#  'aflukning': True,
#  'afluring': True,
#  'aflusning': True,
#  'aflyd': True,
#  'aflysning': True,
#  'aflytning': True,
#  'aflæggelse': True,
#  'aflæggeplads': True,
#  'aflægger': True,
#  'aflægning': True,
#  'aflæring': True,
#  'aflæser': True,
#  'aflæsning': True,
#  'aflæsser': True,
#  'afløb': False,
#  'afløbsrør': False,
#  'aflønning': True,
#  'afløser': True,
#  'afløsning': True,
#  'afløvning': True,
#  'aflåsning': True,
#  'afmagnetisering': True,
#  'afmagring': True,
#  'afmagringskur': True,
#  'afmagt': True,
#  'afmarch': True,
#  'afmatning': True,
#  'afmattelse': True,
#  'afmejning': True,
#  'afmeldelse': True,
#  'afmelding': True,
#  'afmilitarisering': True,
#  'afmontering': True,
#  'afmystificering': True,
#  'afmytologisering': True,
#  'afmærkning': True,
#  'afmønstring': True,
#  'afmåling': True,
#  'afnakning': True,
#  'afnationalisering': True,
#  'afnazificering': True,
#  'aforisme': True,
#  'afparering': True,
#  'afpasning': True,
#  'afpatruljering': True,
#  'afpersonalisering': True,
#  'afplukning': True,
#  'afpolitisering': True,
#  'afpresning': True,
#  'afpresser': True,
#  'afprivatisering': True,
#  'afpropning': True,
#  'afprøvning': True,
#  'afpuds': False,
#  'afpudsning': True,
#  'afpæling': True,
#  'afrapportering': True,
#  'afreagering': True,
#  'afreaktion': True,
#  'afregistrering': True,
#  'afregning': True,
#  'afregulering': True,
#  'afrejse': True,
#  'afrejsedato': True,
#  'afrensning': True,
#  'afretning': True,
#  'afrettelse': True,
#  'afretter': True,
#  'afrids': False,
#  'afridsning': True,
#  'afrigning': True,
#  'afrikaaner': True,
#  'afrikaans': False,
#  'afrikaner': True,
#  'afrikanisering': True,
#  'afrimning': True,
#  'afrivning': True,
#  'afroamerikaner': True,
#  'afrodisiakum': False,
#  'afrohår': False,
#  'afrunding': True,
#  'afrusning': True,
#  'afrustning': True,
#  'afrydder': True,
#  'afrydning': True,
#  'afrømning': True,
#  'afsats': True,
#  'afsavn': False,
#  'afsendelse': True,
#  'afsender': True,
#  'afsigelse': True,
#  'afsikring': True,
#  'afsind': False,
#  'afsindighed': True,
#  'afskaffelse': True,
#  'afskalling': True,
#  'afskalning': True,
#  'afsked': True,
#  'afskedigelse': True,
#  'afskedsbegæring': True,
#  'afskedsreception': True,
#  'afskedssalut': True,
#  'afskedtagen': False,
#  'afskiber': True,
#  'afskibning': True,
#  'afskovning': True,
#  'afskrab': False,
#  'afskraber': True,
#  'afskrabning': True,
#  'afskridtning': True,
#  'afskrift': True,
#  'afskrivning': True,
#  'afskrækkelse': True,
#  'afskrælning': True,
#  'afskum': False,
#  'afskumning': True,
#  'afsky': True,
#  'afskydning': True,
#  'afskyelighed': True,
#  'afskygning': True,
#  'afskæring': True,
#  'afskærmning': True,
#  'afslag': False,
#  'afslapning': True,
#  'afslappelse': True,
#  'afslibning': True,
#  'afslutning': True,
#  'afslutningsfest': True,
#  'afslutter': True,
#  'afsløring': True,
#  'afsmag': True,
#  'afsmeltning': True,
#  'afsminkning': True,
#  'afsmitning': True,
#  'afsnit': False,
#  'afsnøring': True,
#  'afsondring': True,
#  'afsoner': True,
#  'afsoning': True,
#  'afspadsering': True,
#  'afspaltning': True,
#  'afspejling': True,
#  'afspiller': True,
#  'afspilning': True,
#  'afspisning': True,
#  'afsporing': True,
#  'afspritning': True,
#  'afspænding': True,
#  'afspændingsmiddel': False,
#  'afspændingspædagog': True,
#  'afspærring': True,
#  'afstamning': True,
#  'afstand': True,
#  'afstandsmåler': True,
#  'afstandtagen': False,
#  'afstemning': True,
#  'afstigning': True,
#  'afstikker': True,
#  'afstikning': True,
#  'afstivning': True,
#  'afstraffelse': True,
#  'afstresning': True,
#  'afstribning': True,
#  'afstrømning': True,
#  'afstumpning': True,
#  'afstøbning': True,
#  'afstødning': True,
#  'afstøvning': True,
#  'afståelse': True,
#  'afsvaling': True,
#  'afsvidning': True,
#  'afsvovling': True,
#  'afsvækkelse': True,
#  'afsvækning': True,
#  'afsværgelse': True,
#  'afsyngelse': True,
#  'afsyngning': True,
#  'afsyring': True,
#  'afsæbning': True,
#  'afsæt': False,
#  'afsætning': True,
#  'afsættelse': True,
#  'afsøgning': True,
#  'aftabuisering': True,
#  'aftag': False,
#  'aftager': True,
#  'aftagning': True,
#  'aftakling': True,
#  'aftale': True,
#  'aftapning': True,
#  'aftegn': False,
#  'aftegning': True,
#  'aften': True,
#  'aftenbrug': True,
#  'aftenbøn': True,
#  'aftenflade': True,
#  'aftengudstjeneste': True,
#  'aftenkaffe': True,
#  'aftenrøde': True,
#  'aftensang': True,
#  'aftensbord': False,
#  'aftenskole': True,
#  'aftensmad': True,
#  'aftensmåltid': False,
#  'aftensol': True,
#  'aftenstid': False,
#  'aftenstjerne': True,
#  'aftenstund': True,
#  'aftensværmer': True,
#  'aftentur': True,
#  'aftenvagt': True,
#  'afterbeat': False,
#  'afterparty': False,
#  'aftershave': True,
#  'afterski': True,
#  'afterskiing': True,
#  'aftersun': False,
#  'aftes': False,
#  'aftjekning': True,
#  'aftjening': True,
#  'aftrapning': True,
#  'aftryk': False,
#  'aftrykning': True,
#  'aftrædelse': True,
#  'aftrædning': True,
#  'aftræk': False,
#  'aftrækker': True,
#  'aftvingelse': True,
#  'aftægt': True,
#  'aftørring': True,
#  'afvalmning': True,
#  'afvanding': True,
#  'afvandring': True,
#  'afvarsling': True,
#  'afvaskning': True,
#  'afvej': True,
#  'afvejning': True,
#  'afveksling': True,
#  'afvendelse': True,
#  'afventning': True,
#  'afvigelse': True,
#  'afviger': True,
#  'afvikler': True,
#  'afvikling': True,
#  'afvisersten': True,
#  'afvisning': True,
#  'afvæbning': True,
#  'afvænning': True,
#  'afværgedagsorden': True,
#  'afværgelse': True,
#  'afværgemanøvre': True,
#  'afæskning': True,
#  'agape': True,
#  'agat': True,
#  'agave': True,
#  'agenda': True,
#  'agende': True,
#  'agens': True,
#  'agent': True,
#  'agentur': False,
#  'ager': True,
#  'agerbrug': False,
#  'agerbruger': True,
#  'agerdyrker': True,
#  'agerdyrkning': True,
#  'agerhøne': True,
#  'agerjord': True,
#  'agerkål': True,
#  'agerland': False,
#  'agermåne': True,
#  'agern': False,
#  'agerren': True,
#  'agersennep': True,
#  'agersnegl': True,
#  'agersnerle': True,
#  'agertidsel': True,
#  'agglomerat': False,
#  'agglutination': True,
#  'agglutinering': True,
#  'aggravation': True,
#  'aggravering': True,
#  'aggregat': False,
#  'aggregering': True,
#  'aggression': True,
#  'aggressivitet': True,
#  'aggressor': True,
#  'agilitet': True,
#  'agility': False,
#  'agio': True,
#  'agitation': True,
#  'agitator': True,
#  'agn': True,
#  'agnat': True,
#  'agnfisk': True,
#  'agnosticisme': True,
#  'agnostiker': True,
#  'agoni': True,
#  'agora': True,
#  'agorafobi': True,
#  'agrar': True,
#  'agrarpolitik': True,
#  'agrarøkonom': True,
#  'agrikultur': True,
#  'agronom': True,
#  'agronomi': True,
#  'agt': False,
#  'agtelse': True,
#  'agterparti': False,
#  'agterskib': False,
#  'agterskrivelse': True,
#  'agterspejl': False,
#  'agterstavn': True,
#  'agterstævn': True,
#  'agtpågivenhed': True,
#  'agurk': True,
#  'agurkesalat': True,
#  'agurkestav': True,
#  'agurketid': True,
#  'ahaoplevelse': True,
#  'A-hold': False,
#  'ahorn': True,
#  'ahornsirup': True,
#  'ahorntræ': False,
#  'aids': True,
#  'aidspatient': True,
#  'aids-patient': True,
#  'aikido': True,
#  'A-indkomst': True,
#  'aioli': True,
#  'air': False,
#  'airbag': True,
#  'airbrush': True,
#  'aircondition': False,
#  'airedaleterrier': True,
#  'ais': False,
#  'ajle': True,
#  'ajourføring': True,
#  'akacie': True,
#  'akademi': False,
#  'akademiker': True,
#  'akademisering': True,
#  'akademisme': True,
#  'akantus': True,
#  'a-kasse': True,
#  'akeleje': True,
#  'akilleshæl': True,
#  'akillessene': True,
#  'akklamation': True,
#  'akklimatisation': True,
#  'akklimatisering': True,
#  'akkolade': True,
#  'akkommodation': True,
#  'akkompagnatør': True,
#  'akkompagnement': False,
#  'akkord': True,
#  'akkordarbejde': False,
#  'akkordeon': False,
#  'akkordering': True,
#  'akkordræs': False,
#  'akkreditering': True,
#  'akkreditiv': False,
#  'akkumulation': True,
#  'akkumulator': True,
#  'akkumulering': True,
#  'akkuratesse': True,
#  'akkusativ': True,
#  'akkvisition': True,
#  'akne': True,
#  'a-kraft': True,
#  'a-kraftværk': False,
#  'akribi': True,
#  'akrobat': True,
#  'akrobatik': True,
#  'akromegali': True,
#  'akronym': False,
#  'akrostikon': False,
#  'akryl': True,
#  'akrylmaling': True,
#  'aks': False,
#  'akse': True,
#  'aksel': True,
#  'akselafstand': True,
#  'akseltryk': False,
#  'aksgræs': False,
#  'aksiom': False,
#  'akt': True,
#  'aktant': True,
#  'aktantmodel': True,
#  'aktering': True,
#  'aktie': True,
#  'aktieanalytiker': True,
#  'aktiecertifikat': False,
#  'aktiekapital': True,
#  'aktiemajoritet': True,
#  'aktiepost': True,
#  'aktieselskab': False,
#  'aktindsigt': True,
#  'aktion': True,
#  'aktionering': True,
#  'aktionsart': True,
#  'aktionsradius': True,
#  'aktionær': True,
#  'aktionærkonto': True,
#  'aktiv': True,
#  'aktivering': True,
#  'aktivferie': True,
#  'aktivisering': True,
#  'aktivisme': True,
#  'aktivist': True,
#  'aktivitet': True,
#  'aktivitetscenter': False,
#  'aktivitetshus': False,
#  'aktivitetsniveau': False,
#  'aktor': True,
#  'aktorat': False,
#  'aktrice': True,
#  'aktstykke': False,
#  'aktualisering': True,
#  'aktualitet': True,
#  'aktuar': True,
#  'aktør': True,
#  'akupressur': True,
#  'akupunktur': True,
#  'akupunktør': True,
#  'akustik': True,
#  'akustiker': True,
#  'akuthjælp': True,
#  'akuthjælper': True,
#  'akutklinik': True,
#  'akutmodtagelse': True,
#  'akvakultur': True,
#  'akvamarin': True,
#  'akvaplaning': True,
#  'akvarel': True,
#  'akvarie': False,
#  'akvarist': True,
#  'akvarium': False,
#  'akvatinte': True,
#  'akvavit': True,
#  'akvifer': True,
#  'akvædukt': True,
#  'al': True,
#  'alabast': True,
#  'alabasterkrukke': True,
#  'alabastlampe': True,
#  'alabastvase': True,
#  'a la carte-ret': True,
#  'a la grecque-bort': True,
#  'alarm': True,
#  'alarmberedskab': False,
#  'alarmcentral': True,
#  'alarmering': True,
#  'alarmklokke': True,
#  'alarmsignal': False,
#  'alarmsystem': False,
#  'alarmtilstand': True,
#  'alba': True,
#  'albaner': True,
#  'albatros': True,
#  'albinisme': True,
#  'albino': True,
#  'albue': True,
#  'albueben': False,
#  'albueled': False,
#  'albuerum': False,
#  'albuestød': False,
#  'album': False,
#  'albumin': False,
#  'aldehyd': False,
#  'alder': True,
#  'alderdom': True,
#  'alderdomshjem': False,
#  'aldersdiabetes': False,
#  'aldersdiabetiker': True,
#  'aldersdiskrimination': True,
#  'aldersdiskriminering': True,
#  'aldersformand': True,
#  'aldersgruppe': True,
#  'aldersgrænse': True,
#  'alderspension': True,
#  'alderspensionist': True,
#  'alderspræsident': True,
#  'aldersspredning': True,
#  'alderstrin': False,
#  'aldring': True,
#  'aldringsproces': True,
#  'ale': True,
#  'aleksandriner': True,
#  'aleksi': True,
#  'alemanner': True,
#  'alen': True,
#  'alenefar': True,
#  'alenemor': True,
#  'alenetilværelse': True,
#  'aleneulykke': True,
#  'alf': True,
#  'alfa': False,
#  'alfabet': False,
#  'alfabetisering': True,
#  'alfahan': True,
#  'alfapartikel': True,
#  'alfarvej': True,
#  'alfastråle': True,
#  'alfastråling': True,
#  'alfons': True,
#  'alfonseri': False,
#  'alge': True,
#  'algebra': True,
#  'algerier': True,
#  'algoritme': True,
#  'alhede': True,
#  'alhus': False,
#  'alias': False,
#  'alibi': False,
#  'alien': False,
#  'alienation': True,
#  'alimentation': True,
#  'alinea': False,
#  'alk': True,
#  'alkali': False,
#  'alkaloid': False,
#  'alkefugl': True,
#  'alkohol': True,
#  'alkoholambulatorie': False,
#  'alkoholambulatorium': False,
#  'alkoholbevilling': True,
#  'alkoholiker': True,
#  'alkoholisering': True,
#  'alkoholisme': True,
#  'alkoholist': True,
#  'alkoholmisbrug': True,
#  'alkoholmisbruger': True,
#  'alkoholpolitik': True,
#  'alkometer': False,
#  'alkove': True,
#  'alkvantor': True,
#  'alkyd': True,
#  'alkydmaling': True,
#  'alkymi': True,
#  'alkymist': True,
#  'allé': True,
#  'allegori': True,
#  'allegorisering': True,
#  'allegretto': True,
#  'allegro': True,
#  'allehelgensdag': True,
#  'allehånde': False,
#  'allemande': True,
#  'allemandseje': False,
#  'allemandsret': True,
#  'allergen': False,
#  'allergi': True,
#  'allergiker': True,
#  'allergitest': True,
#  'allergolog': True,
#  'allergologi': True,
#  'allesjælesdag': True,
#  'allestedsnærværelse': True,
#  'alliance': True,
#  'alliancering': True,
#  'alliancesyltetøj': False,
#  'alligator': True,
#  'allike': True,
#  'allingebo': True,
#  'allitteration': True,
#  'allokation': True,
#  'allokering': True,
#  'allonge': True,
#  'allongeparyk': True,
#  'allroundviden': False,
#  'allusion': True,
#  'alluvialtid': True,
#  'almagt': True,
#  'almanak': True,
#  'almanakhistorie': True,
#  'almenbefindende': False,
#  'almendannelse': True,
#  'almeneje': False,
#  'almenhed': True,
#  'almeninteresse': True,
#  'almensprog': False,
#  'almenvel': False,
#  'almenviden': False,
#  'almindelighed': True,
#  'alminding': True,
#  'almisse': True,
#  'almue': True,
#  'almuestil': True,
#  'aloe': True,
#  'alp': True,
#  'alpaka': True,
#  'alpehorn': False,
#  'alpehue': True,
#  'alperose': True,
#  'alpeviol': True,
#  'alpinisme': True,
#  'alpinist': True,
#  'alrum': False,
#  'alrune': True,
#  'alsacer': True,
#  'alsang': True,
#  'alsidighed': True,
#  'alsikekløver': True,
#  'alsing': True,
#  'alsinger': True,
#  'alt': True,
#  'altan': True,
#  'altangang': True,
#  'altankasse': True,
#  'alter': False,
#  'alteration': True,
#  'alterbog': True,
#  'alter ego': False,
#  'altergang': True,
#  'alterkalk': True,
#  'alternation': True,
#  'alternativ': False,
#  'alternativsamfund': False,
#  'alternering': True,
#  'altertavle': True,
#  'altertjeneste': True,
#  'alting': False,
#  'altmuligmand': True,
#  'altnøgle': True,
#  'altruisme': True,
#  'altruist': True,
#  'altsax': True,
#  'altsaxofon': True,
#  'altsaxofonist': True,
#  'altstemme': True,
#  'altvejrsjakke': True,
#  'altæabolsje': False,
#  'alufolie': True,
#  'aluminium': False,
#  'alumne': True,
#  'alun': True,
#  'alveolar': True,
#  'alveolarrand': True,
#  'alveole': True,
#  'alverden': False,
#  'alvidenhed': True,
#  'alvor': True,
#  'alvorsmand': True,
#  'alvorsord': False,
#  'alzheimerpatient': True,
#  'Alzheimers sygdom': False,
#  'amager': True,
#  'amagergarn': False,
#  'amagerhylde': True,
#  'amagerkaner': True,
#  'amagermad': True,
#  'amalgam': False,
#  'amalgamation': True,
#  'amalgamering': True,
#  'amanuensis': True,
#  'amarant': True,
#  'amarantfarve': True,
#  'amarone': True,
#  'amaryllis': True,
#  'amatør': True,
#  'amatørfoto': False,
#  'amatørfotograf': True,
#  'amatørisme': True,
#  'amatørorkester': False,
#  ...}

# %%
import pickle

with open("/Users/lucasvilsen/Desktop/GrammatikTAK/Datasets/GenderDict.pickle", "wb") as f:
    pickle.dump(dictionary_is_fælleskøn, f)

# %% [markdown]
# ---
# ### Stem dicts

# %%
# Substantiv

sb_dict = {}
current_lst = []
for i, row in tqdm(df.iterrows()):
    if row['bøjning'] == "sb." and row['ord1'] == df.iloc[i-1]['ord1']:
        first_word = row['ord1']
        current_lst += [row['ord2']]
        if row['ord1'] not in current_lst:
            current_lst += [row['ord1']]
    elif len(current_lst) > 0:
        for value in list(set(current_lst)):
            sb_dict[value] = first_word
        current_lst = []
        first_word = ""
    elif row['bøjning'] == "sb.":
        first_word = row['ord1']
        current_lst += [row['ord1'], row['ord2']]
# Out:
# 415437it [00:16, 24751.71it/s]

# %%
sb_dict
# Out:
# {"A'ets": 'A',
#  "A'er": 'A',
#  "A'ers": 'A',
#  "A'ernes": 'A',
#  "A'erne": 'A',
#  'A': 'A',
#  "A'et": 'A',
#  "A's": 'A',
#  "a'et": 'a',
#  "a'er": 'a',
#  "a'erne": 'a',
#  "a'ernes": 'a',
#  "a'ers": 'a',
#  "a's": 'a',
#  "a'ets": 'a',
#  'a': 'a',
#  'A3-formatet': 'A3-format',
#  'A3-format': 'A3-format',
#  'A3-formatets': 'A3-format',
#  'A3-formats': 'A3-format',
#  'A4-format': 'A4-format',
#  'A4-formats': 'A4-format',
#  'A4-formatet': 'A4-format',
#  'A4-formatets': 'A4-format',
#  'A5-formats': 'A5-format',
#  'A5-format': 'A5-format',
#  'A5-formatets': 'A5-format',
#  'A5-formatet': 'A5-format',
#  'A-aktie': 'A-aktie',
#  'A-aktiens': 'A-aktie',
#  'A-aktiers': 'A-aktie',
#  'A-aktien': 'A-aktie',
#  'A-aktiernes': 'A-aktie',
#  'A-akties': 'A-aktie',
#  'A-aktier': 'A-aktie',
#  'A-aktierne': 'A-aktie',
#  'abandonneringen': 'abandonnering',
#  'abandonneringens': 'abandonnering',
#  'abandonnering': 'abandonnering',
#  'abandonneringers': 'abandonnering',
#  'abandonneringernes': 'abandonnering',
#  'abandonneringerne': 'abandonnering',
#  'abandonneringer': 'abandonnering',
#  'abandonnerings': 'abandonnering',
#  'abbederne': 'abbed',
#  'abbeders': 'abbed',
#  'abbeder': 'abbed',
#  'abbeden': 'abbed',
#  'abbedens': 'abbed',
#  'abbed': 'abbed',
#  'abbeds': 'abbed',
#  'abbedernes': 'abbed',
#  'abbediet': 'abbedi',
#  'abbediets': 'abbedi',
#  'abbedi': 'abbedi',
#  'abbedierne': 'abbedi',
#  'abbedier': 'abbedi',
#  'abbediernes': 'abbedi',
#  'abbediers': 'abbedi',
#  'abbedis': 'abbedi',
#  'abbedisse': 'abbedisse',
#  'abbedissens': 'abbedisse',
#  'abbedissen': 'abbedisse',
#  'abbedisserne': 'abbedisse',
#  'abbedisses': 'abbedisse',
#  'abbedissernes': 'abbedisse',
#  'abbedisser': 'abbedisse',
#  'abbedissers': 'abbedisse',
#  "ABC'erne": 'ABC',
#  "ABC'er": 'ABC',
#  "ABC'ens": 'ABC',
#  'ABC': 'ABC',
#  "ABC'en": 'ABC',
#  "ABC'ernes": 'ABC',
#  "ABC's": 'ABC',
#  "ABC'ers": 'ABC',
#  "abc'en": 'abc',
#  "abc'erne": 'abc',
#  "abc's": 'abc',
#  "abc'ens": 'abc',
#  "abc'ers": 'abc',
#  'abc': 'abc',
#  "abc'er": 'abc',
#  "abc'ernes": 'abc',
#  'abdiceringen': 'abdicering',
#  'abdiceringernes': 'abdicering',
#  'abdiceringerne': 'abdicering',
#  'abdiceringer': 'abdicering',
#  'abdicering': 'abdicering',
#  'abdicerings': 'abdicering',
#  'abdiceringens': 'abdicering',
#  'abdiceringers': 'abdicering',
#  'abdikationens': 'abdikation',
#  'abdikationer': 'abdikation',
#  'abdikationernes': 'abdikation',
#  'abdikationers': 'abdikation',
#  'abdikation': 'abdikation',
#  'abdikations': 'abdikation',
#  'abdikationen': 'abdikation',
#  'abdikationerne': 'abdikation',
#  'aberne': 'abe',
#  'aben': 'abe',
#  'abes': 'abe',
#  'abe': 'abe',
#  'abers': 'abe',
#  'aber': 'abe',
#  'abernes': 'abe',
#  'abens': 'abe',
#  'abefesten': 'abefest',
#  'abefests': 'abefest',
#  'abefesternes': 'abefest',
#  'abefester': 'abefest',
#  'abefesterne': 'abefest',
#  'abefest': 'abefest',
#  'abefestens': 'abefest',
#  'abefesters': 'abefest',
#  'abekatte': 'abekat',
#  'abekattenes': 'abekat',
#  'abekattene': 'abekat',
#  'abekattes': 'abekat',
#  'abekatten': 'abekat',
#  'abekats': 'abekat',
#  'abekat': 'abekat',
#  'abekattens': 'abekat',
#  'abekattestreg': 'abekattestreg',
#  'abekattestregers': 'abekattestreg',
#  'abekattestregs': 'abekattestreg',
#  'abekattestregerne': 'abekattestreg',
#  'abekattestregernes': 'abekattestreg',
#  'abekattestregen': 'abekattestreg',
#  'abekattestreger': 'abekattestreg',
#  'abekattestregens': 'abekattestreg',
#  'abemenneskernes': 'abemenneske',
#  'abemenneskenes': 'abemenneske',
#  'abemenneskers': 'abemenneske',
#  'abemenneskets': 'abemenneske',
#  'abemenneske': 'abemenneske',
#  'abemenneskerne': 'abemenneske',
#  'abemennesket': 'abemenneske',
#  'abemenneskene': 'abemenneske',
#  'abemenneskes': 'abemenneske',
#  'abemennesker': 'abemenneske',
#  'aber dabeis': 'aber dabei',
#  'aber dabei': 'aber dabei',
#  'aberrationer': 'aberration',
#  'aberrationers': 'aberration',
#  'aberrationen': 'aberration',
#  'aberrationernes': 'aberration',
#  'aberrations': 'aberration',
#  'aberrationerne': 'aberration',
#  'aberration': 'aberration',
#  'aberrationens': 'aberration',
#  'abessiner': 'abessiner',
#  'abessineren': 'abessiner',
#  'abessiners': 'abessiner',
#  'abessinernes': 'abessiner',
#  'abessinerne': 'abessiner',
#  'abessinerens': 'abessiner',
#  'abessineres': 'abessiner',
#  'abessinere': 'abessiner',
#  'abessinier': 'abessinier',
#  'abessinierne': 'abessinier',
#  'abessinieren': 'abessinier',
#  'abessinierens': 'abessinier',
#  'abessiniere': 'abessinier',
#  'abessinieres': 'abessinier',
#  'abessiniers': 'abessinier',
#  'abessiniernes': 'abessinier',
#  'abetræet': 'abetræ',
#  'abetræs': 'abetræ',
#  'abetræers': 'abetræ',
#  'abetræ': 'abetræ',
#  'abetræets': 'abetræ',
#  'abetræer': 'abetræ',
#  'abetræernes': 'abetræ',
#  'abetræerne': 'abetræ',
#  'abkhaseren': 'abkhaser',
#  'abkhaseres': 'abkhaser',
#  'abkhasers': 'abkhaser',
#  'abkhaserens': 'abkhaser',
#  'abkhaserne': 'abkhaser',
#  'abkhasere': 'abkhaser',
#  'abkhaser': 'abkhaser',
#  'abkhasernes': 'abkhaser',
#  'ablativernes': 'ablativ',
#  'ablativ': 'ablativ',
#  'ablativen': 'ablativ',
#  'ablativs': 'ablativ',
#  'ablativers': 'ablativ',
#  'ablativerne': 'ablativ',
#  'ablativer': 'ablativ',
#  'ablativens': 'ablativ',
#  'abnormitets': 'abnormitet',
#  'abnormitetens': 'abnormitet',
#  'abnormiteters': 'abnormitet',
#  'abnormiteter': 'abnormitet',
#  'abnormitet': 'abnormitet',
#  'abnormiteten': 'abnormitet',
#  'abnormiteterne': 'abnormitet',
#  'abnormiteternes': 'abnormitet',
#  'a-bombernes': 'a-bombe',
#  'a-bombe': 'a-bombe',
#  'a-bombens': 'a-bombe',
#  'a-bombes': 'a-bombe',
#  'a-bombers': 'a-bombe',
#  'a-bomben': 'a-bombe',
#  'a-bomber': 'a-bombe',
#  'a-bomberne': 'a-bombe',
#  'abonnements': 'abonnement',
#  'abonnementernes': 'abonnement',
#  'abonnementer': 'abonnement',
#  'abonnementerne': 'abonnement',
#  'abonnementers': 'abonnement',
#  'abonnement': 'abonnement',
#  'abonnementet': 'abonnement',
#  'abonnementets': 'abonnement',
#  'abonnents': 'abonnent',
#  'abonnenter': 'abonnent',
#  'abonnenters': 'abonnent',
#  'abonnent': 'abonnent',
#  'abonnenten': 'abonnent',
#  'abonnentens': 'abonnent',
#  'abonnenterne': 'abonnent',
#  'abonnenternes': 'abonnent',
#  'abonneringer': 'abonnering',
#  'abonneringerne': 'abonnering',
#  'abonneringen': 'abonnering',
#  'abonneringens': 'abonnering',
#  'abonnering': 'abonnering',
#  'abonneringernes': 'abonnering',
#  'abonneringers': 'abonnering',
#  'abonnerings': 'abonnering',
#  'abonninens': 'abonnine',
#  'abonniner': 'abonnine',
#  'abonniners': 'abonnine',
#  'abonninernes': 'abonnine',
#  'abonninen': 'abonnine',
#  'abonnine': 'abonnine',
#  'abonnines': 'abonnine',
#  'abonninerne': 'abonnine',
#  'aboriginal': 'aboriginal',
#  'aboriginalen': 'aboriginal',
#  'aboriginals': 'aboriginal',
#  "aboriginals'": 'aboriginal',
#  'aboriginalens': 'aboriginal',
#  'aboriginerens': 'aboriginer',
#  'aboriginere': 'aboriginer',
#  'aborigineren': 'aboriginer',
#  'aboriginer': 'aboriginer',
#  'aborigineres': 'aboriginer',
#  'aboriginers': 'aboriginer',
#  'aboriginernes': 'aboriginer',
#  'aboriginerne': 'aboriginer',
#  'aborrens': 'aborre',
#  'aborrernes': 'aborre',
#  'aborres': 'aborre',
#  'aborrer': 'aborre',
#  'aborrerne': 'aborre',
#  'aborre': 'aborre',
#  'aborrers': 'aborre',
#  'aborren': 'aborre',
#  'aborten': 'abort',
#  'abort': 'abort',
#  'aborternes': 'abort',
#  'aborts': 'abort',
#  'abortens': 'abort',
#  'aborterne': 'abort',
#  'aborters': 'abort',
#  'aborter': 'abort',
#  'abortmodstanderen': 'abortmodstander',
#  'abortmodstandernes': 'abortmodstander',
#  'abortmodstandere': 'abortmodstander',
#  'abortmodstanders': 'abortmodstander',
#  'abortmodstander': 'abortmodstander',
#  'abortmodstanderne': 'abortmodstander',
#  'abortmodstanderes': 'abortmodstander',
#  'abortmodstanderens': 'abortmodstander',
#  'abracadabra': 'abracadabra',
#  'abracadabras': 'abracadabra',
#  'A-breves': 'A-brev',
#  'A-brevs': 'A-brev',
#  'A-brevene': 'A-brev',
#  'A-brevenes': 'A-brev',
#  'A-breve': 'A-brev',
#  'A-brev': 'A-brev',
#  'A-brevets': 'A-brev',
#  'A-brevet': 'A-brev',
#  "abrikos'": 'abrikos',
#  'abrikoserne': 'abrikos',
#  'abrikosen': 'abrikos',
#  'abrikoser': 'abrikos',
#  'abrikosernes': 'abrikos',
#  'abrikosers': 'abrikos',
#  'abrikos': 'abrikos',
#  'abrikosens': 'abrikos',
#  'ABS': 'ABS',
#  "ABS'ens": 'ABS',
#  "ABS'en": 'ABS',
#  "ABS'": 'ABS',
#  "abs'": 'abs',
#  "abs'ens": 'abs',
#  'abs': 'abs',
#  "abs'en": 'abs',
#  'abscesserne': 'absces',
#  'abscessens': 'absces',
#  'abscesser': 'absces',
#  "absces'": 'absces',
#  'abscessen': 'absces',
#  'absces': 'absces',
#  'abscessernes': 'absces',
#  'abscessers': 'absces',
#  'abscisse': 'abscisse',
#  'abscissen': 'abscisse',
#  'abscissers': 'abscisse',
#  'abscissernes': 'abscisse',
#  'abscisser': 'abscisse',
#  'abscisserne': 'abscisse',
#  'abscissens': 'abscisse',
#  'abscisses': 'abscisse',
#  'abscisseakser': 'abscisseakse',
#  'abscisseaksers': 'abscisseakse',
#  'abscisseakse': 'abscisseakse',
#  'abscisseakserne': 'abscisseakse',
#  'abscisseakses': 'abscisseakse',
#  'abscisseaksernes': 'abscisseakse',
#  'abscisseaksen': 'abscisseakse',
#  'abscisseaksens': 'abscisseakse',
#  'absencen': 'absence',
#  'absencer': 'absence',
#  'absencernes': 'absence',
#  'absence': 'absence',
#  'absences': 'absence',
#  'absencens': 'absence',
#  'absencerne': 'absence',
#  'absencers': 'absence',
#  'absentationer': 'absentation',
#  'absentationens': 'absentation',
#  'absentationerne': 'absentation',
#  'absentationers': 'absentation',
#  'absentationernes': 'absentation',
#  'absentationen': 'absentation',
#  'absentations': 'absentation',
#  'absentation': 'absentation',
#  'absenteringens': 'absentering',
#  'absenteringers': 'absentering',
#  'absenteringen': 'absentering',
#  'absenterings': 'absentering',
#  'absentering': 'absentering',
#  'absenteringernes': 'absentering',
#  'absenteringer': 'absentering',
#  'absenteringerne': 'absentering',
#  'absintens': 'absint',
#  'absinten': 'absint',
#  'absints': 'absint',
#  'absinternes': 'absint',
#  'absinter': 'absint',
#  'absinterne': 'absint',
#  'absint': 'absint',
#  'absinters': 'absint',
#  'absoluts': 'absolut',
#  'absolutterne': 'absolut',
#  'absolutternes': 'absolut',
#  'absoluttet': 'absolut',
#  'absolutter': 'absolut',
#  'absoluttets': 'absolut',
#  'absolut': 'absolut',
#  'absolutters': 'absolut',
#  'absolutionernes': 'absolution',
#  'absolutionens': 'absolution',
#  'absolutions': 'absolution',
#  'absolutionerne': 'absolution',
#  'absolutioners': 'absolution',
#  'absolutioner': 'absolution',
#  'absolution': 'absolution',
#  'absolutionen': 'absolution',
#  'absolutisme': 'absolutisme',
#  'absolutismes': 'absolutisme',
#  'absolutismen': 'absolutisme',
#  'absolutismens': 'absolutisme',
#  'absolutister': 'absolutist',
#  'absolutisters': 'absolutist',
#  'absolutisten': 'absolutist',
#  'absolutisternes': 'absolutist',
#  'absolutists': 'absolutist',
#  'absolutistens': 'absolutist',
#  'absolutist': 'absolutist',
#  'absolutisterne': 'absolutist',
#  'absorberingernes': 'absorbering',
#  'absorberingen': 'absorbering',
#  'absorbering': 'absorbering',
#  'absorberinger': 'absorbering',
#  'absorberingers': 'absorbering',
#  'absorberingens': 'absorbering',
#  'absorberingerne': 'absorbering',
#  'absorberings': 'absorbering',
#  'absorptionen': 'absorption',
#  'absorptions': 'absorption',
#  'absorptionens': 'absorption',
#  'absorptioners': 'absorption',
#  'absorptioner': 'absorption',
#  'absorption': 'absorption',
#  'absorptionerne': 'absorption',
#  'absorptionernes': 'absorption',
#  'abstinens': 'abstinens',
#  "abstinens'": 'abstinens',
#  'abstinensen': 'abstinens',
#  'abstinenser': 'abstinens',
#  'abstinensernes': 'abstinens',
#  'abstinensers': 'abstinens',
#  'abstinensens': 'abstinens',
#  'abstinenserne': 'abstinens',
#  'abstracternes': 'abstract',
#  'abstracts': 'abstract',
#  'abstracter': 'abstract',
#  'abstracterne': 'abstract',
#  'abstractet': 'abstract',
#  'abstractets': 'abstract',
#  "abstracts'": 'abstract',
#  'abstract': 'abstract',
#  'abstracters': 'abstract',
#  'abstraheringer': 'abstrahering',
#  'abstraheringen': 'abstrahering',
#  'abstraheringens': 'abstrahering',
#  'abstraheringernes': 'abstrahering',
#  'abstraheringerne': 'abstrahering',
#  'abstraherings': 'abstrahering',
#  'abstrahering': 'abstrahering',
#  'abstraheringers': 'abstrahering',
#  'abstraktet': 'abstrakt',
#  'abstrakterne': 'abstrakt',
#  'abstraktets': 'abstrakt',
#  'abstrakters': 'abstrakt',
#  'abstrakt': 'abstrakt',
#  'abstrakter': 'abstrakt',
#  'abstrakternes': 'abstrakt',
#  'abstrakts': 'abstrakt',
#  'abstraktioner': 'abstraktion',
#  'abstraktionerne': 'abstraktion',
#  'abstraktion': 'abstraktion',
#  'abstraktionen': 'abstraktion',
#  'abstraktioners': 'abstraktion',
#  'abstraktionernes': 'abstraktion',
#  'abstraktions': 'abstraktion',
#  'abstraktionens': 'abstraktion',
#  'absurdismen': 'absurdisme',
#  'absurdismes': 'absurdisme',
#  'absurdisme': 'absurdisme',
#  'absurdismens': 'absurdisme',
#  'absurdister': 'absurdist',
#  'absurdisterne': 'absurdist',
#  'absurdisters': 'absurdist',
#  'absurdists': 'absurdist',
#  'absurdist': 'absurdist',
#  'absurdisternes': 'absurdist',
#  'absurdisten': 'absurdist',
#  'absurdistens': 'absurdist',
#  'absurditetens': 'absurditet',
#  'absurditeternes': 'absurditet',
#  'absurditeterne': 'absurditet',
#  'absurditet': 'absurditet',
#  'absurditeter': 'absurditet',
#  'absurditets': 'absurditet',
#  'absurditeters': 'absurditet',
#  'absurditeten': 'absurditet',
#  'abyssinierens': 'abyssinier',
#  'abyssinierne': 'abyssinier',
#  'abyssiniernes': 'abyssinier',
#  'abyssinier': 'abyssinier',
#  'abyssinieren': 'abyssinier',
#  'abyssinieres': 'abyssinier',
#  'abyssiniers': 'abyssinier',
#  'abyssiniere': 'abyssinier',
#  'acaibærs': 'acaibær',
#  'acaibærrenes': 'acaibær',
#  'acaibærret': 'acaibær',
#  'acaibær': 'acaibær',
#  'acaibærrene': 'acaibær',
#  'acaibærrets': 'acaibær',
#  'accelerationen': 'acceleration',
#  'accelerationer': 'acceleration',
#  'acceleration': 'acceleration',
#  'accelerationens': 'acceleration',
#  'accelerationernes': 'acceleration',
#  'accelerationers': 'acceleration',
#  'accelerationerne': 'acceleration',
#  'accelerations': 'acceleration',
#  'acceleratorer': 'accelerator',
#  'accelerator': 'accelerator',
#  'acceleratorerne': 'accelerator',
#  'accelerators': 'accelerator',
#  'acceleratorernes': 'accelerator',
#  'acceleratorers': 'accelerator',
#  'acceleratoren': 'accelerator',
#  'acceleratorens': 'accelerator',
#  'accent': 'accent',
#  'accenter': 'accent',
#  'accenters': 'accent',
#  'accenternes': 'accent',
#  'accents': 'accent',
#  'accentens': 'accent',
#  'accenten': 'accent',
#  'accenterne': 'accent',
#  'accenttegnets': 'accenttegn',
#  'accenttegnene': 'accenttegn',
#  'accenttegnet': 'accenttegn',
#  'accenttegn': 'accenttegn',
#  'accenttegns': 'accenttegn',
#  'accenttegnenes': 'accenttegn',
#  'accentuationers': 'accentuation',
#  'accentuationernes': 'accentuation',
#  'accentuation': 'accentuation',
#  'accentuationens': 'accentuation',
#  'accentuationerne': 'accentuation',
#  'accentuations': 'accentuation',
#  'accentuationen': 'accentuation',
#  'accentuationer': 'accentuation',
#  'accentuering': 'accentuering',
#  'accentuerings': 'accentuering',
#  'accentueringernes': 'accentuering',
#  'accentueringer': 'accentuering',
#  'accentueringerne': 'accentuering',
#  'accentueringen': 'accentuering',
#  'accentueringens': 'accentuering',
#  'accentueringers': 'accentuering',
#  'accepterne': 'accept',
#  'accepter': 'accept',
#  'accepts': 'accept',
#  'accepten': 'accept',
#  'acceptens': 'accept',
#  'accept': 'accept',
#  'accepters': 'accept',
#  'accepternes': 'accept',
#  'accessen': 'acces',
#  'accesserne': 'acces',
#  'accessers': 'acces',
#  'accessens': 'acces',
#  'accessernes': 'acces',
#  "acces'": 'acces',
#  'accesser': 'acces',
#  'acces': 'acces',
#  'accession': 'accession',
#  'accessions': 'accession',
#  'accessioners': 'accession',
#  'accessioner': 'accession',
#  'accessionen': 'accession',
#  'accessionens': 'accession',
#  'accessionernes': 'accession',
#  'accessionerne': 'accession',
#  'acetatets': 'acetat',
#  'acetater': 'acetat',
#  'acetat': 'acetat',
#  'acetatet': 'acetat',
#  'acetaternes': 'acetat',
#  'acetats': 'acetat',
#  'acetaterne': 'acetat',
#  'acetaters': 'acetat',
#  'acetone': 'acetone',
#  'acetonernes': 'acetone',
#  'acetoners': 'acetone',
#  'acetones': 'acetone',
#  'acetonens': 'acetone',
#  'acetoner': 'acetone',
#  'acetonen': 'acetone',
#  'acetonerne': 'acetone',
#  'acetylets': 'acetyl',
#  'acetyls': 'acetyl',
#  'acetyl': 'acetyl',
#  'acetylens': 'acetylen',
#  'acetylen': 'acetylen',
#  'acetylet': 'acetyl',
#  'acetylenet': 'acetylen',
#  'acetylenets': 'acetylen',
#  'acetylsalicylsyres': 'acetylsalicylsyre',
#  'acetylsalicylsyre': 'acetylsalicylsyre',
#  'acetylsalicylsyren': 'acetylsalicylsyre',
#  'acetylsalicylsyrens': 'acetylsalicylsyre',
#  "acidofilus'": 'acidofilus',
#  'acidofilus': 'acidofilus',
#  'a conto-beløbets': 'a conto-beløb',
#  'a conto-beløbs': 'a conto-beløb',
#  'a conto-beløbenes': 'a conto-beløb',
#  'a conto-beløbene': 'a conto-beløb',
#  'a conto-beløbet': 'a conto-beløb',
#  'a conto-beløb': 'a conto-beløb',
#  'acontobeløbs': 'acontobeløb',
#  'acontobeløbets': 'acontobeløb',
#  'acontobeløbet': 'acontobeløb',
#  'acontobeløbene': 'acontobeløb',
#  'acontobeløbenes': 'acontobeløb',
#  'acontobeløb': 'acontobeløb',
#  'action': 'action',
#  'actions': 'action',
#  'actionfilmens': 'actionfilm',
#  'actionfilmene': 'actionfilm',
#  'actionfilmenes': 'actionfilm',
#  'actionfilmen': 'actionfilm',
#  'actionfilms': 'actionfilm',
#  'actionfilm': 'actionfilm',
#  "AD'er": 'AD',
#  "AD'erne": 'AD',
#  "AD's": 'AD',
#  "AD'ernes": 'AD',
#  'AD': 'AD',
#  "AD'en": 'AD',
#  "AD'ens": 'AD',
#  "AD'ers": 'AD',
#  "ad'erne": 'ad',
#  "ad'ernes": 'ad',
#  "ad'ers": 'ad',
#  'ad': 'ad',
#  "ad'ens": 'ad',
#  "ad's": 'ad',
#  "ad'en": 'ad',
#  "ad'er": 'ad',
#  'adagioen': 'adagio',
#  'adagioers': 'adagio',
#  'adagioet': 'adagio',
#  'adagio': 'adagio',
#  'adagioernes': 'adagio',
#  'adagios': 'adagio',
#  'adagioer': 'adagio',
#  'adagioets': 'adagio',
#  'adagioens': 'adagio',
#  'adagioerne': 'adagio',
#  'adamskostumet': 'adamskostume',
#  'adamskostumets': 'adamskostume',
#  'adamskostume': 'adamskostume',
#  'adamskostumes': 'adamskostume',
#  'adamsæblers': 'adamsæble',
#  'adamsæblet': 'adamsæble',
#  'adamsæblerne': 'adamsæble',
#  'adamsæblets': 'adamsæble',
#  'adamsæbler': 'adamsæble',
#  'adamsæbles': 'adamsæble',
#  'adamsæblernes': 'adamsæble',
#  'adamsæble': 'adamsæble',
#  'adaptationen': 'adaptation',
#  'adaptationernes': 'adaptation',
#  'adaptations': 'adaptation',
#  'adaptationers': 'adaptation',
#  'adaptationerne': 'adaptation',
#  'adaptation': 'adaptation',
#  'adaptationer': 'adaptation',
#  'adaptationens': 'adaptation',
#  'adapteren': 'adapter',
#  'adaptere': 'adapter',
#  'adapters': 'adapter',
#  'adapternes': 'adapter',
#  'adapteres': 'adapter',
#  'adapterens': 'adapter',
#  'adapterne': 'adapter',
#  'adapter': 'adapter',
#  'adaptions': 'adaption',
#  'adaptioner': 'adaption',
#  'adaption': 'adaption',
#  'adaptionens': 'adaption',
#  'adaptionernes': 'adaption',
#  'adaptionen': 'adaption',
#  'adaptioners': 'adaption',
#  'adaptionerne': 'adaption',
#  'addendernes': 'addend',
#  'addenden': 'addend',
#  'addender': 'addend',
#  'addenderne': 'addend',
#  'addend': 'addend',
#  'addendens': 'addend',
#  'addenders': 'addend',
#  'addends': 'addend',
#  'adderinger': 'addering',
#  'adderingers': 'addering',
#  'addering': 'addering',
#  'adderingens': 'addering',
#  'adderings': 'addering',
#  'adderingernes': 'addering',
#  'adderingen': 'addering',
#  'adderingerne': 'addering',
#  'additioners': 'addition',
#  'additions': 'addition',
#  'additioner': 'addition',
#  'additionens': 'addition',
#  'additionen': 'addition',
#  'addition': 'addition',
#  'additionerne': 'addition',
#  'additionernes': 'addition',
#  'additiverne': 'additiv',
#  'additivet': 'additiv',
#  'additivers': 'additiv',
#  'additivs': 'additiv',
#  'additivets': 'additiv',
#  'additivernes': 'additiv',
#  'additiver': 'additiv',
#  'additiv': 'additiv',
#  'adels': 'adel',
#  'adlen': 'adel',
#  'adlens': 'adel',
#  'adel': 'adel',
#  'adelen': 'adel',
#  'adelens': 'adel',
#  'adelskabet': 'adelskab',
#  'adelskabs': 'adelskab',
#  'adelskab': 'adelskab',
#  'adelskabets': 'adelskab',
#  'adelskvinderne': 'adelskvinde',
#  'adelskvinde': 'adelskvinde',
#  'adelskvinders': 'adelskvinde',
#  'adelskvindernes': 'adelskvinde',
#  'adelskvinden': 'adelskvinde',
#  'adelskvindes': 'adelskvinde',
#  'adelskvindens': 'adelskvinde',
#  'adelskvinder': 'adelskvinde',
#  'adelsmandens': 'adelsmand',
#  'adelsmændenes': 'adelsmand',
#  'adelsmænds': 'adelsmand',
#  'adelsmændene': 'adelsmand',
#  'adelsmand': 'adelsmand',
#  'adelsmænd': 'adelsmand',
#  'adelsmands': 'adelsmand',
#  'adelsmanden': 'adelsmand',
#  'adelsmærke': 'adelsmærke',
#  'adelsmærkes': 'adelsmærke',
#  'adelsmærkers': 'adelsmærke',
#  'adelsmærkets': 'adelsmærke',
#  'adelsmærker': 'adelsmærke',
#  'adelsmærkerne': 'adelsmærke',
#  'adelsmærkernes': 'adelsmærke',
#  'adelsmærket': 'adelsmærke',
#  'adelstands': 'adelstand',
#  'adelstand': 'adelstand',
#  'adelstanden': 'adelstand',
#  'adelstandens': 'adelstand',
#  'adelsvældets': 'adelsvælde',
#  'adelsvælden': 'adelsvælde',
#  'adelsvældes': 'adelsvælde',
#  'adelsvælde': 'adelsvælde',
#  'adelsvældet': 'adelsvælde',
#  'adelsvældens': 'adelsvælde',
#  'adfærds': 'adfærd',
#  'adfærd': 'adfærd',
#  'adfærden': 'adfærd',
#  'adfærdens': 'adfærd',
#  'adfærdenes': 'adfærd',
#  'adfærdene': 'adfærd',
#  'adfærdsmønstrene': 'adfærdsmønster',
#  'adfærdsmønsterets': 'adfærdsmønster',
#  'adfærdsmønsters': 'adfærdsmønster',
#  'adfærdsmønstrets': 'adfærdsmønster',
#  'adfærdsmønster': 'adfærdsmønster',
#  'adfærdsmønstres': 'adfærdsmønster',
#  'adfærdsmønsteret': 'adfærdsmønster',
#  'adfærdsmønstrenes': 'adfærdsmønster',
#  'adfærdsmønstre': 'adfærdsmønster',
#  'adfærdsmønstret': 'adfærdsmønster',
#  'adfærdsreguleringers': 'adfærdsregulering',
#  'adfærdsreguleringer': 'adfærdsregulering',
#  'adfærdsregulering': 'adfærdsregulering',
#  'adfærdsreguleringerne': 'adfærdsregulering',
#  'adfærdsreguleringens': 'adfærdsregulering',
#  'adfærdsreguleringernes': 'adfærdsregulering',
#  'adfærdsregulerings': 'adfærdsregulering',
#  'adfærdsreguleringen': 'adfærdsregulering',
#  'adfærdsterapierne': 'adfærdsterapi',
#  'adfærdsterapier': 'adfærdsterapi',
#  'adfærdsterapi': 'adfærdsterapi',
#  'adfærdsterapiens': 'adfærdsterapi',
#  'adfærdsterapiernes': 'adfærdsterapi',
#  'adfærdsterapien': 'adfærdsterapi',
#  'adfærdsterapiers': 'adfærdsterapi',
#  'adfærdsterapis': 'adfærdsterapi',
#  'adgange': 'adgang',
#  'adgangens': 'adgang',
#  'adgangenes': 'adgang',
#  'adgangen': 'adgang',
#  'adgangene': 'adgang',
#  'adgangs': 'adgang',
#  'adganges': 'adgang',
#  'adgang': 'adgang',
#  'adgangsbegrænsninger': 'adgangsbegrænsning',
#  'adgangsbegrænsnings': 'adgangsbegrænsning',
#  'adgangsbegrænsningen': 'adgangsbegrænsning',
#  'adgangsbegrænsningerne': 'adgangsbegrænsning',
#  'adgangsbegrænsningernes': 'adgangsbegrænsning',
#  'adgangsbegrænsningers': 'adgangsbegrænsning',
#  'adgangsbegrænsning': 'adgangsbegrænsning',
#  'adgangsbegrænsningens': 'adgangsbegrænsning',
#  'adgangseksamenernes': 'adgangseksamen',
#  'adgangseksaminer': 'adgangseksamen',
#  'adgangseksamenerne': 'adgangseksamen',
#  'adgangseksamen': 'adgangseksamen',
#  'adgangseksamenens': 'adgangseksamen',
#  'adgangseksaminerne': 'adgangseksamen',
#  'adgangseksaminers': 'adgangseksamen',
#  'adgangseksamens': 'adgangseksamen',
#  'adgangseksamenen': 'adgangseksamen',
#  'adgangseksamener': 'adgangseksamen',
#  'adgangseksameners': 'adgangseksamen',
#  'adgangseksaminernes': 'adgangseksamen',
#  'adgangsprøvers': 'adgangsprøve',
#  'adgangsprøvernes': 'adgangsprøve',
#  'adgangsprøver': 'adgangsprøve',
#  'adgangsprøven': 'adgangsprøve',
#  'adgangsprøve': 'adgangsprøve',
#  'adgangsprøverne': 'adgangsprøve',
#  'adgangsprøves': 'adgangsprøve',
#  'adgangsprøvens': 'adgangsprøve',
#  'adhærence': 'adhærence',
#  'adhærencernes': 'adhærence',
#  'adhærencen': 'adhærence',
#  'adhærencers': 'adhærence',
#  'adhærences': 'adhærence',
#  'adhærencer': 'adhærence',
#  'adhærencerne': 'adhærence',
#  'adhærencens': 'adhærence',
#  'adhærensen': 'adhærens',
#  'adhærensers': 'adhærens',
#  'adhærens': 'adhærens',
#  "adhærens'": 'adhærens',
#  'adhærensens': 'adhærens',
#  'adhærenserne': 'adhærens',
#  'adhærenser': 'adhærens',
#  'adhærensernes': 'adhærens',
#  'adhæsionens': 'adhæsion',
#  'adhæsionen': 'adhæsion',
#  'adhæsion': 'adhæsion',
#  'adhæsions': 'adhæsion',
#  'adjektivets': 'adjektiv',
#  'adjektivernes': 'adjektiv',
#  'adjektivs': 'adjektiv',
#  'adjektiver': 'adjektiv',
#  'adjektiv': 'adjektiv',
#  'adjektivet': 'adjektiv',
#  'adjektiverne': 'adjektiv',
#  'adjektivers': 'adjektiv',
#  'adjudantens': 'adjudant',
#  'adjudanten': 'adjudant',
#  'adjudants': 'adjudant',
#  'adjudanterne': 'adjudant',
#  'adjudanternes': 'adjudant',
#  'adjudant': 'adjudant',
#  'adjudanters': 'adjudant',
#  'adjudanter': 'adjudant',
#  'adjudanturers': 'adjudantur',
#  'adjudanturernes': 'adjudantur',
#  'adjudanturerne': 'adjudantur',
#  'adjudanturen': 'adjudantur',
#  'adjudanturs': 'adjudantur',
#  'adjudantur': 'adjudantur',
#  'adjudanturer': 'adjudantur',
#  'adjudanturens': 'adjudantur',
#  'adjunkter': 'adjunkt',
#  'adjunkters': 'adjunkt',
#  'adjunkts': 'adjunkt',
#  'adjunkternes': 'adjunkt',
#  'adjunkten': 'adjunkt',
#  'adjunkt': 'adjunkt',
#  'adjunktens': 'adjunkt',
#  'adjunkterne': 'adjunkt',
#  'adjunkturet': 'adjunktur',
#  'adjunktur': 'adjunktur',
#  'adjunkturerne': 'adjunktur',
#  'adjunkturets': 'adjunktur',
#  'adjunkturs': 'adjunktur',
#  'adjunkturers': 'adjunktur',
#  'adjunkturernes': 'adjunktur',
#  'adjunkturer': 'adjunktur',
#  'adkomsters': 'adkomst',
#  'adkomsternes': 'adkomst',
#  'adkomstens': 'adkomst',
#  'adkomster': 'adkomst',
#  'adkomsten': 'adkomst',
#  'adkomst': 'adkomst',
#  'adkomsts': 'adkomst',
#  'adkomsterne': 'adkomst',
#  'adleddet': 'adled',
#  'adleds': 'adled',
#  'adleddenes': 'adled',
#  'adled': 'adled',
#  'adleddets': 'adled',
#  'adleddene': 'adled',
#  'adling': 'adling',
#  'adlingen': 'adling',
#  'adlingens': 'adling',
#  'adlingers': 'adling',
#  'adlingerne': 'adling',
#  'adlinger': 'adling',
#  'adlingernes': 'adling',
#  'adlings': 'adling',
#  'administrationens': 'administration',
#  'administrationer': 'administration',
#  'administrations': 'administration',
#  'administrationernes': 'administration',
#  'administrationers': 'administration',
#  'administrationen': 'administration',
#  'administration': 'administration',
#  'administrationerne': 'administration',
#  'administratorers': 'administrator',
#  'administrators': 'administrator',
#  'administrator': 'administrator',
#  'administratoren': 'administrator',
#  'administratorens': 'administrator',
#  'administratorerne': 'administrator',
#  'administratorer': 'administrator',
#  'administratorernes': 'administrator',
#  'administreringen': 'administrering',
#  'administreringens': 'administrering',
#  'administrering': 'administrering',
#  'administrerings': 'administrering',
#  'admiralernes': 'admiral',
#  'admiraler': 'admiral',
#  'admiralers': 'admiral',
#  'admiral': 'admiral',
#  'admirals': 'admiral',
#  'admiralens': 'admiral',
#  'admiralen': 'admiral',
#  'admiralerne': 'admiral',
#  'admiralitet': 'admiralitet',
#  'admiralitets': 'admiralitet',
#  'admiraliteterne': 'admiralitet',
#  'admiralitetet': 'admiralitet',
#  'admiraliteternes': 'admiralitet',
#  'admiraliteters': 'admiralitet',
#  'admiraliteter': 'admiralitet',
#  'admiralitetets': 'admiralitet',
#  'adonissers': 'adonis',
#  'adonisserne': 'adonis',
#  'adonissernes': 'adonis',
#  'adonissen': 'adonis',
#  'adonisser': 'adonis',
#  'adonis': 'adonis',
#  "adonis'": 'adonis',
#  'adonissens': 'adonis',
#  'adoptanternes': 'adoptant',
#  'adoptanterne': 'adoptant',
#  'adoptant': 'adoptant',
#  'adoptantens': 'adoptant',
#  'adoptanter': 'adoptant',
#  'adoptanters': 'adoptant',
#  'adoptanten': 'adoptant',
#  'adoptants': 'adoptant',
#  'adopteringerne': 'adoptering',
#  'adopteringernes': 'adoptering',
#  'adopteringen': 'adoptering',
#  'adopteringer': 'adoptering',
#  'adopteringers': 'adoptering',
#  'adopterings': 'adoptering',
#  'adopteringens': 'adoptering',
#  'adoptering': 'adoptering',
#  'adoptioner': 'adoption',
#  'adoptionernes': 'adoption',
#  'adoptioners': 'adoption',
#  'adoptionen': 'adoption',
#  'adoption': 'adoption',
#  'adoptionerne': 'adoption',
#  'adoptionens': 'adoption',
#  'adoptions': 'adoption',
#  'adoptivbarns': 'adoptivbarn',
#  'adoptivbørnene': 'adoptivbarn',
#  'adoptivbarnet': 'adoptivbarn',
#  'adoptivbørns': 'adoptivbarn',
#  'adoptivbarnets': 'adoptivbarn',
#  'adoptivbørn': 'adoptivbarn',
#  'adoptivbørnenes': 'adoptivbarn',
#  'adoptivbarn': 'adoptivbarn',
#  'adrenalin': 'adrenalin',
#  'adrenalinet': 'adrenalin',
#  'adrenalinens': 'adrenalin',
#  'adrenalinets': 'adrenalin',
#  'adrenalinen': 'adrenalin',
#  'adrenalins': 'adrenalin',
#  'adressaten': 'adressat',
#  'adressaterne': 'adressat',
#  'adressatens': 'adressat',
#  'adressaters': 'adressat',
#  'adressater': 'adressat',
#  'adressats': 'adressat',
#  'adressat': 'adressat',
#  'adressaternes': 'adressat',
#  'adresses': 'adresse',
#  'adressers': 'adresse',
#  'adresserne': 'adresse',
#  'adresse': 'adresse',
#  'adressen': 'adresse',
#  'adressens': 'adresse',
#  'adressernes': 'adresse',
#  'adresser': 'adresse',
#  'adressebøger': 'adressebog',
#  'adressebogens': 'adressebog',
#  'adressebogs': 'adressebog',
#  'adressebøgernes': 'adressebog',
#  'adressebøgers': 'adressebog',
#  'adressebøgerne': 'adressebog',
#  'adressebogen': 'adressebog',
#  'adressebog': 'adressebog',
#  'adressekortets': 'adressekort',
#  'adressekortene': 'adressekort',
#  'adressekortenes': 'adressekort',
#  'adressekorts': 'adressekort',
#  'adressekortet': 'adressekort',
#  'adressekort': 'adressekort',
#  'adresseringers': 'adressering',
#  'adresseringens': 'adressering',
#  ...}

# %%
with open("/Users/lucasvilsen/Desktop/GrammatikTAK/Datasets/SbStemDict.pickle", "wb") as f:
    pickle.dump(sb_dict, f)

# %%
# verbs

import pandas as pd
from tqdm import tqdm

df = pd.read_csv("/Users/lucasvilsen/Desktop/GrammatikTAK/Datasets/ordlisteFuldform2021rettet.csv")
df = df

vb_dict = {}
stem_to_bøjninger = {}
nutids_r = {}
nutids_r_stem = {}
current_lst = []
lengths = []
for i, row in tqdm(df.iterrows()):
    if row['bøjning'] == "vb." and row['ord1'] == df.iloc[i-1]['ord1']:
        first_word = row['ord1']
        if row['ord2'] not in current_lst:
            current_lst += [row['ord2']]
        if first_word not in current_lst:
            current_lst += [first_word]
    elif len(current_lst) > 0:
        for value in current_lst:
            vb_dict[value] = first_word
        #print(current_lst[0], current_lst[1], current_lst[0] == current_lst[1])
        if current_lst[0] == current_lst[1]:
            current_lst = current_lst[1:]
        stem_to_bøjninger[first_word] = current_lst
        #print(current_lst)
        lengths.append(len(current_lst))
        infinitiv = current_lst[0]
        nutids_r_word = ""
        for word in current_lst:
            if word == infinitiv + "r":
                nutids_r_word = word
                break
        if len(nutids_r_word) > 0:
            nutids_r[first_word] = [infinitiv, nutids_r_word]
            nutids_r_stem[infinitiv] = first_word
            nutids_r_stem[nutids_r_word] = first_word
        current_lst = []
        first_word = ""
    elif row['bøjning'] == "vb.":
        first_word = row['ord1']
        current_lst += [row['ord1'], row['ord2']]
# Out:
# 415437it [00:10, 40923.79it/s]

# %%
def count(word1, lst):
    current_count = 0
    for word in lst:
        if word == word1 + "r":
            current_count += 1
    if current_count > 1:
        return True
    return False

nutids_r_bøjninger = {}
nutids_r_stem = {}
not_correct = []
for bøjninger in tqdm(stem_to_bøjninger.values()):
    if len(bøjninger) < 4: 
        not_correct.append(bøjninger)
        continue
    infinitiv = bøjninger[0]
    nutids_r = bøjninger[3]
    if nutids_r.replace(infinitiv, "") == "r":
        if count(infinitiv, bøjninger):
            not_correct.append(bøjninger) 
            continue
        nutids_r_bøjninger[infinitiv] = [infinitiv, nutids_r]
        nutids_r_stem[infinitiv] = infinitiv
        nutids_r_stem[nutids_r] = infinitiv
    else: 
        infinitiv = bøjninger[1]
        nutids_r = bøjninger[3]
        if nutids_r.replace(infinitiv, "") == "r":
            if count(infinitiv, bøjninger):
                not_correct.append(bøjninger) 
                continue
            nutids_r_bøjninger[infinitiv] = [infinitiv, nutids_r]
            nutids_r_stem[infinitiv] = infinitiv
            nutids_r_stem[nutids_r] = infinitiv
        else:
            infinitiv = bøjninger[0]
            nutids_r = ""
            for word in bøjninger:
                if word == infinitiv + "r":
                    nutids_r = word
            if len(nutids_r) > 0:
                nutids_r_bøjninger[infinitiv] = [infinitiv, nutids_r]
                nutids_r_stem[infinitiv] = infinitiv
                nutids_r_stem[nutids_r] = infinitiv
            else:
                infinitiv = bøjninger[0]
                nutids_r = bøjninger[1]
                if infinitiv.replace(nutids_r, "") == "e":
                    nutids_r_bøjninger[infinitiv] = [infinitiv, nutids_r]
                    nutids_r_stem[infinitiv] = infinitiv
                    nutids_r_stem[nutids_r] = infinitiv
                else:
                    infinitiv = bøjninger[1]
                    nutids_r = ""
                    for word in bøjninger:
                        if word == infinitiv + "r":
                            nutids_r = word
                    if len(nutids_r) > 0:
                        nutids_r_bøjninger[infinitiv] = [infinitiv, nutids_r]
                        nutids_r_stem[infinitiv] = infinitiv
                        nutids_r_stem[nutids_r] = infinitiv
                    else:
                        not_correct.append(bøjninger)
# Out:
# 100%|██████████| 7038/7038 [00:00<00:00, 407126.37it/s]

# %%
len(not_correct)
# Out:
# 66

# %%
not_added = []
from IPython.display import clear_output

for i, bøjninger in enumerate(not_correct):
    print(str(i) + "/" + str(len(not_correct)))
    print(*zip(list(range(len(bøjninger))), bøjninger), sep="\n")
    infinitiv_key = int(input("Vælg infinitiv: "))
    if infinitiv_key > 20:
        clear_output()
        print("Did not add")
        not_added.append(i)
        continue
    infinitiv = bøjninger[infinitiv_key]
    nutids_r_key = int(input("Vælg nutids-r: "))
    nutids_r = bøjninger[nutids_r_key]
    print(f"Infinitiv = {infinitiv}, nutids-r = {nutids_r}")
    is_correct = int(input("Er dette korrekt?"))
    clear_output()
    if is_correct == 0:
        print("Did not add")
        not_added.append(i)
        continue
    nutids_r_bøjninger[infinitiv] = [infinitiv, nutids_r]
    nutids_r_stem[infinitiv] = infinitiv
    nutids_r_stem[nutids_r] = infinitiv
# Out:
# Did not add

# %% [markdown]
# ##### Needs to be going through these manually

# %%
stem_to_bøjninger["gøre"],
# Out:
# (['gøre', 'gør', 'gjort', 'gørende', 'gjorde', 'gøres', 'gjordes'],)

# %%
nutids_r_stem["gør"], nutids_r_bøjninger["gøre"]
# Out:
# ('gøre', ['gøre', 'gør'])

# %%
nutids_r_bøjninger["spille"]
# Out:
# ['spille', 'spiller']

# %%
import pickle

with open("/Users/lucasvilsen/Desktop/GrammatikTAK/Datasets/VbStemDict.pickle", "wb") as f:
    pickle.dump(vb_dict, f)
with open("/Users/lucasvilsen/Desktop/GrammatikTAK/Datasets/VbStemToBøjningDict.pickle", "wb") as f:
    pickle.dump(stem_to_bøjninger, f)
with open("/Users/lucasvilsen/Desktop/GrammatikTAK/Datasets/nutids_r_bøjninger.pickle", "wb") as f:
    pickle.dump(nutids_r_bøjninger, f)
with open("/Users/lucasvilsen/Desktop/GrammatikTAK/Datasets/nutids_r_stem.pickle", "wb") as f:
    pickle.dump(nutids_r_stem, f)

# %% [markdown]
# ---
# ### Load Dictionaries
